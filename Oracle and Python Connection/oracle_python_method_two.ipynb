# %%
import cx_Oracle
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Connecting with oracle database

# %%
#Database Connection
connection = cx_Oracle.connect(user="hr", password="HR",
                               dsn="oracle.localdomain/orclpdb")
cursor = connection.cursor()
cursor.execute("""
        SELECT * from employees
        """,
       )
records = cursor.fetchall()
print(records)
# Out:
# [(100, 'Steven', 'King', 'SKING', '1.515.555.0100', datetime.datetime(2013, 6, 17, 0, 0), 'AD_PRES', 24000.0, None, None, 90), (101, 'Neena', 'Yang', 'NYANG', '1.515.555.0101', datetime.datetime(2015, 9, 21, 0, 0), 'AD_VP', 17000.0, None, 100, 90), (102, 'Lex', 'Garcia', 'LGARCIA', '1.515.555.0102', datetime.datetime(2011, 1, 13, 0, 0), 'AD_VP', 17000.0, None, 100, 90), (103, 'Alexander', 'James', 'AJAMES', '1.590.555.0103', datetime.datetime(2016, 1, 3, 0, 0), 'IT_PROG', 9000.0, None, 102, 60), (104, 'Bruce', 'Miller', 'BMILLER', '1.590.555.0104', datetime.datetime(2017, 5, 21, 0, 0), 'IT_PROG', 6000.0, None, 103, 60), (105, 'David', 'Williams', 'DWILLIAMS', '1.590.555.0105', datetime.datetime(2015, 6, 25, 0, 0), 'IT_PROG', 4800.0, None, 103, 60), (106, 'Valli', 'Jackson', 'VJACKSON', '1.590.555.0106', datetime.datetime(2016, 2, 5, 0, 0), 'IT_PROG', 4800.0, None, 103, 60), (107, 'Diana', 'Nguyen', 'DNGUYEN', '1.590.555.0107', datetime.datetime(2017, 2, 7, 0, 0), 'IT_PROG', 4200.0, N
# ...

# %% [markdown]
# # Fetching table or query

# %%
#converting to dataframe each table or query
employees = pd.read_sql_query("select * from employees", connection)
employees.head(5)
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME    EMAIL    PHONE_NUMBER  HIRE_DATE  \
# 0          100     Steven      King    SKING  1.515.555.0100 2013-06-17
# 1          101      Neena      Yang    NYANG  1.515.555.0101 2015-09-21
# 2          102        Lex    Garcia  LGARCIA  1.515.555.0102 2011-01-13
# 3          103  Alexander     James   AJAMES  1.590.555.0103 2016-01-03
# 4          104      Bruce    Miller  BMILLER  1.590.555.0104 2017-05-21
#
#     JOB_ID   SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# 0  AD_PRES  24000.0             NaN         NaN           90.0
# 1    AD_VP  17000.0             NaN       100.0           90.0
# 2    AD_VP  17000.0             NaN       100.0           90.0
# 3  IT_PROG   9000.0             NaN       102.0           60.0
# 4  IT_PROG   6000.0             NaN       103.0           60.0

# %%
#converting to dataframe each table or query
regions = pd.read_sql_query("select * from regions", connection)
regions.head(5)
# Out:
#    REGION_ID REGION_NAME
# 0         10      Europe
# 1         20    Americas
# 2         30        Asia
# 3         40     Oceania
# 4         50      Africa

# %%
#converting to dataframe each table or query
countries = pd.read_sql_query("select * from countries", connection)
countries.head(5)
# Out:
#   COUNTRY_ID COUNTRY_NAME  REGION_ID
# 0         AR    Argentina         20
# 1         AU    Australia         40
# 2         BE      Belgium         10
# 3         BR       Brazil         20
# 4         CA       Canada         10

# %%
#converting to dataframe each table or query
locations = pd.read_sql_query("select * from locations", connection)
locations.head(5)
# Out:
#    LOCATION_ID           STREET_ADDRESS POSTAL_CODE       CITY  \
# 0         1000     1297 Via Cola di Rie       00989       Roma
# 1         1100  93091 Calle della Testa       10934     Venice
# 2         1200         2017 Shinjuku-ku        1689      Tokyo
# 3         1300          9450 Kamiya-cho        6823  Hiroshima
# 4         1400      2014 Jabberwocky Rd       26192  Southlake
#
#      STATE_PROVINCE COUNTRY_ID
# 0              None         IT
# 1              None         IT
# 2  Tokyo Prefecture         JP
# 3              None         JP
# 4             Texas         US

# %%
#converting to dataframe each table or query
departments = pd.read_sql_query("select * from departments", connection)
departments.head(5)
# Out:
#    DEPARTMENT_ID  DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0             10   Administration       200.0         1700
# 1             20        Marketing       201.0         1800
# 2             30       Purchasing       114.0         1700
# 3             40  Human Resources       203.0         2400
# 4             50         Shipping       121.0         1500

# %%
#converting to dataframe each table or query
jobs = pd.read_sql_query("select * from jobs", connection)
jobs.head(5)
# Out:
#        JOB_ID                      JOB_TITLE  MIN_SALARY  MAX_SALARY
# 0     AD_PRES                      President       20080       40000
# 1       AD_VP  Administration Vice President       15000       30000
# 2     AD_ASST       Administration Assistant        3000        6000
# 3      FI_MGR                Finance Manager        8200       16000
# 4  FI_ACCOUNT                     Accountant        4200        9000

# %%
#converting to dataframe each table or query
job_history = pd.read_sql_query("select * from job_history", connection)
job_history.head(5)
# Out:
#    EMPLOYEE_ID START_DATE   END_DATE      JOB_ID  DEPARTMENT_ID
# 0          102 2011-01-13 2016-07-24     IT_PROG             60
# 1          101 2007-09-21 2011-10-27  AC_ACCOUNT            110
# 2          101 2011-10-28 2015-03-15      AC_MGR            110
# 3          201 2014-02-17 2017-12-19      MK_REP             20
# 4          114 2016-03-24 2017-12-31    ST_CLERK             50

# %%
# watching user owned table in schema
tables = pd.read_sql_query("select table_name from user_tables order by table_name asc", connection)
tables
# Out:
#     TABLE_NAME
# 0    COUNTRIES
# 1  DEPARTMENTS
# 2    EMPLOYEES
# 3         JOBS
# 4  JOB_HISTORY
# 5    LOCATIONS
# 6      REGIONS

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EMPLOYEE_ID     107 non-null    int64
#  1   FIRST_NAME      107 non-null    object
#  2   LAST_NAME       107 non-null    object
#  3   EMAIL           107 non-null    object
#  4   PHONE_NUMBER    107 non-null    object
#  5   HIRE_DATE       107 non-null    datetime64[ns]
#  6   JOB_ID          107 non-null    object
#  7   SALARY          107 non-null    float64
#  8   COMMISSION_PCT  35 non-null     float64
#  9   MANAGER_ID      106 non-null    float64
#  10  DEPARTMENT_ID   106 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(5)
# memory usage: 9.3+ KB

# %%
 regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   REGION_ID    5 non-null      int64
#  1   REGION_NAME  5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DEPARTMENT_ID    27 non-null     int64
#  1   DEPARTMENT_NAME  27 non-null     object
#  2   MANAGER_ID       11 non-null     float64
#  3   LOCATION_ID      27 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 992.0+ bytes

# %%
salary_with_job_id = pd.read_sql_query("select salary, job_id from employees ", connection)
salary_with_job_id
# Out:
#       SALARY      JOB_ID
# 0    24000.0     AD_PRES
# 1    17000.0       AD_VP
# 2    17000.0       AD_VP
# 3     9000.0     IT_PROG
# 4     6000.0     IT_PROG
# ..       ...         ...
# 102   6000.0      MK_REP
# 103   6500.0      HR_REP
# 104  10000.0      PR_REP
# 105  12008.0      AC_MGR
# 106   8300.0  AC_ACCOUNT
#
# [107 rows x 2 columns]
